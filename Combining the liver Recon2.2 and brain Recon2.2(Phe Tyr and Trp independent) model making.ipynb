# %% [markdown]
# # Adding blood reactions

# %%
import cobra
from cobra import Model, Reaction, Metabolite

M = cobra.io.load_json_model('Recon2.2Brainliver.json')
# Metabolites
## phe related
phe_L_c = M.metabolites.get_by_id('phe_L_c')
phe_L_c_INB = M.metabolites.get_by_id('phe_L_c_INB')
phe_L_BD = Metabolite('phe_L_BD', formula='C9H11NO2',name='L-phenylalanine',compartment='Blood')
phe_L_e_INB = M.metabolites.get_by_id('phe_L_e_INB')
phpyr_e = M.metabolites.get_by_id('phpyr_e')
phpyr_BD = Metabolite('phpyr_BD', formula='C9H7O3',name='keto-phenylpyruvate',compartment='Blood')
phpyr_e_INB =M.metabolites.get_by_id('phpyr_e_INB')
pheP_INB=Metabolite('pheP_INB', formula='',name='phenylalanine product with tyrosine hydroxylase',compartment='Blood')
## tyr related
tyr_L_c = M.metabolites.get_by_id('tyr_L_c')
tyr_L_BD = Metabolite('tyr_L_BD', formula='C9H11NO3',name='L-tyrosine',compartment='Blood')
tyr_L_e_INB = M.metabolites.get_by_id('tyr_L_e_INB')
tyr_L_c_INB = M.metabolites.get_by_id('tyr_L_c_INB')
## His related
his_L_c = M.metabolites.get_by_id('his_L_c')
his_L_BD = Metabolite('his_L_BD', formula='C6H9N3O2',name='L-histidine',compartment='Blood')
his_L_e_INB = M.metabolites.get_by_id('his_L_e_INB')
## ile related
ile_L_c = M.metabolites.get_by_id('ile_L_c')
ile_L_BD = Metabolite('ile_L_BD', formula='C6H13NO2',name='L-isoleucine',compartment='Blood')
ile_L_e_INB = M.metabolites.get_by_id('ile_L_e_INB')
## leu related
leu_L_c = M.metabolites.get_by_id('leu_L_c')
leu_L_BD = Metabolite('leu_L_BD', formula='C6H13NO2',name='L-leucine',compartment='Blood')
leu_L_e_INB = M.metabolites.get_by_id('leu_L_e_INB')
## met related
met_L_c = M.metabolites.get_by_id('met_L_c')
met_L_BD = Metabolite('met_L_BD', formula='C5H11NO2S',name='L-methionine',compartment='Blood')
met_L_e_INB = M.metabolites.get_by_id('met_L_e_INB')
## thr related
thr_L_c = M.metabolites.get_by_id('thr_L_c')
thr_L_BD = Metabolite('thr_L_BD', formula='C4H9NO3',name='L-threonine',compartment='Blood')
thr_L_e_INB = M.metabolites.get_by_id('thr_L_e_INB')
## trp related
trp_L_c = M.metabolites.get_by_id('trp_L_c')
trp_L_BD = Metabolite('trp_L_BD', formula='C11H12N2O2',name='L-tryptophan',compartment='Blood')
trp_L_e_INB = M.metabolites.get_by_id('trp_L_e_INB')
## val related
val_L_c = M.metabolites.get_by_id('val_L_c')
val_L_BD = Metabolite('val_L_BD', formula='C5H11NO2',name='L-valine',compartment='Blood')
val_L_e_INB = M.metabolites.get_by_id('val_L_e_INB')
## lys related
lys_L_c = M.metabolites.get_by_id('lys_L_c')
lys_L_BD = Metabolite('lys_L_BD', formula='C6H14N2O2',name='L-lysine',compartment='Blood')
lys_L_e_INB = M.metabolites.get_by_id('lys_L_e_INB')
## ala related
ala_L_c = M.metabolites.get_by_id('ala_L_c')
ala_L_BD = Metabolite('ala_L_BD', formula='C3H7NO2',name='L-alanine',compartment='Blood')
ala_L_e_INB = M.metabolites.get_by_id('ala_L_e_INB')
## arg related
arg_L_c = M.metabolites.get_by_id('arg_L_c')
arg_L_BD = Metabolite('arg_L_BD', formula='C6H14N4O2',name='L-arginine',compartment='Blood')
arg_L_e_INB = M.metabolites.get_by_id('arg_L_e_INB')
## asn related
asn_L_c = M.metabolites.get_by_id('asn_L_c')
asn_L_BD = Metabolite('asn_L_BD', formula='C4H8N2O3',name='L-asparagine',compartment='Blood')
asn_L_e_INB = M.metabolites.get_by_id('asn_L_e_INB')
## asp related
asp_L_c = M.metabolites.get_by_id('asp_L_c')
asp_L_BD = Metabolite('asp_L_BD', formula='C4H7NO4',name='L-aspartic acid',compartment='Blood')
asp_L_e_INB = M.metabolites.get_by_id('asp_L_e_INB')
## cys related
cys_L_c = M.metabolites.get_by_id('cys_L_c')
cys_L_BD = Metabolite('cys_L_BD', formula='C3H7NO2S',name='L-cysteine',compartment='Blood')
cys_L_e_INB = M.metabolites.get_by_id('cys_L_e_INB')
## glu related
glu_L_c = M.metabolites.get_by_id('glu_L_c')
glu_L_BD = Metabolite('glu_L_BD', formula='C5H9NO4',name='L-glutamic acid',compartment='Blood')
glu_L_e_INB = M.metabolites.get_by_id('glu_L_e_INB')
## gln related
gln_L_c = M.metabolites.get_by_id('gln_L_c')
gln_L_BD = Metabolite('gln_L_BD', formula='C5H9NO4',name='L-glutamine',compartment='Blood')
gln_L_e_INB = M.metabolites.get_by_id('gln_L_e_INB')
## gly related
gly_c = M.metabolites.get_by_id('gly_c')
gly_BD = Metabolite('gly_BD', formula='C2H5NO2',name='glycine',compartment='Blood')
gly_e_INB = M.metabolites.get_by_id('gly_e_INB')
## pro related
pro_L_c = M.metabolites.get_by_id('pro_L_c')
pro_L_BD = Metabolite('pro_L_BD', formula='C5H9NO2',name='L-proline',compartment='Blood')
pro_L_e_INB = M.metabolites.get_by_id('pro_L_e_INB')
## ser related
ser_L_c = M.metabolites.get_by_id('ser_L_c')
ser_L_BD = Metabolite('ser_L_BD', formula='C3H7NO3',name='L-serine',compartment='Blood')
ser_L_e_INB = M.metabolites.get_by_id('ser_L_e_INB')
## O2 related
o2_c = M.metabolites.get_by_id('o2_c')
o2_BD = Metabolite('o2_BD', formula='O2',name='dioxygen',compartment='Blood')
o2_e_INB = M.metabolites.get_by_id('o2_e_INB')
## NH4 related
nh4_c = M.metabolites.get_by_id('nh4_c')
nh4_BD = Metabolite('nh4_BD', formula='H4N',name='ammonium',compartment='Blood')
nh4_e_INB = M.metabolites.get_by_id('nh4_e_INB')
## Pi related
pi_c = M.metabolites.get_by_id('pi_c')
pi_BD = Metabolite('pi_BD', formula='HO4P',name='hydrogenphosphate',compartment='Blood')
pi_e_INB = M.metabolites.get_by_id('pi_e_INB')


## Transporter 11 related (For Phe)
To11_BD=Metabolite('To11_BD',name='transporter11_out blood',compartment='Blood')
To11_c_BD=Metabolite('To11_c_BD',name='transporter 11 in cell blood',compartment='Blood')
Ti11_INB=Metabolite('Ti11_INB',name='transporter 11 in brain',compartment='Brain')
## Transporter 12 related (For Tyr)
To12_BD=Metabolite('To12_BD',name='transporter12_out blood',compartment='Blood')
To12_c_BD=Metabolite('To12_c_BD',name='transporter 12 in cell blood',compartment='Blood')
Ti12_INB=Metabolite('Ti12_INB',name='transporter 12 in brain',compartment='Brain')
## Transporter 13 related (For Trp)
To13_BD=Metabolite('To13_BD',name='transporter13_out blood',compartment='Blood')
To13_c_BD=Metabolite('To13_c_BD',name='transporter 13 in cell blood',compartment='Blood')
Ti13_INB=Metabolite('Ti13_INB',name='transporter 13 in brain',compartment='Brain')
## Transporter 14 related (For L-dopa)
To14_BD=Metabolite('To14_BD',name='transporter14_out blood',compartment='Blood')
To14_c_BD=Metabolite('To14_c_BD',name='transporter 14 in cell blood',compartment='Blood')
Ti14_INB=Metabolite('Ti14_INB',name='transporter 14 in brain',compartment='Brain')
## Transporter 2 related (For His, Ile, Leu, Met, Thr and Val)
To2_BD=Metabolite('To2_BD',name='transporter2_out blood',compartment='Blood')
To2_c_BD=Metabolite('To2_c_BD',name='transporter 2 in cell blood',compartment='Blood')
Ti2_INB=Metabolite('Ti2_INB',name='transporter 2 in brain',compartment='Brain')
## Transporter 3 related (For Lys)
To3_BD=Metabolite('To3_BD',name='transporter3_out blood',compartment='Blood')
To3_c_BD=Metabolite('To3_c_BD',name='transporter 3 in cell blood',compartment='Blood')
Ti3_INB=Metabolite('Ti3_INB',name='transporter 3 in brain',compartment='Brain')
## Transporter 4 related (For Ala, Arg, Asn, Asp, Cys, Glu, Gln, Gly, Pro and ser)
To4_BD=Metabolite('To4_BD',name='transporter4_out blood',compartment='Blood')
To4_c_BD=Metabolite('To4_c_BD',name='transporter 4 in cell blood',compartment='Blood')
Ti4_INB=Metabolite('Ti4_INB',name='transporter 4 in brain',compartment='Brain')
## Transporter 5 related (For glucose)
To5_BD=Metabolite('To5_BD',name='transporter5_out blood',compartment='Blood')
To5_c_BD=Metabolite('To5_c_BD',name='transporter 5 in cell blood',compartment='Blood')
Ti5_INB=Metabolite('Ti5_INB',name='transporter 5 in brain',compartment='Brain')
## Transporter 6 related (For o2)
To6_BD=Metabolite('To6_BD',name='transporter6_out blood',compartment='Blood')
To6_c_BD=Metabolite('To6_c_BD',name='transporter 6 in cell blood',compartment='Blood')
Ti6_INB=Metabolite('Ti6_INB',name='transporter 6 in brain',compartment='Brain')
## Transporter 7 related (For nh4)
To7_BD=Metabolite('To7_BD',name='transporter7_out blood',compartment='Blood')
To7_c_BD=Metabolite('To7_c_BD',name='transporter 7 in cell blood',compartment='Blood')
Ti7_INB=Metabolite('Ti7_INB',name='transporter 7 in brain',compartment='Brain')
## Transporter 8 related (For pi)
To8_BD=Metabolite('To8_BD',name='transporter8_out blood',compartment='Blood')
To8_c_BD=Metabolite('To8_c_BD',name='transporter 8 in cell blood',compartment='Blood')
Ti8_INB=Metabolite('Ti8_INB',name='transporter 8 in brain',compartment='Brain')

## L-dopa
metabolite=M.metabolites.get_by_id('34dhphe_e_INB')
metabolite1=M.metabolites.get_by_id('34dhphe_c')
metabolite2=Metabolite('34dhphe_BD', formula='C9H11NO4',name='L-dopa',compartment='Blood')
metabolite3=M.metabolites.get_by_id('34dhphe_c_INB')
## Tyrosine Hydroxylase
TH_A_INB = Metabolite('TH_A_INB', formula='',name='Tyrosine Hydroxylase after reaction',compartment='Brain')
TH_B_INB = Metabolite('TH_B_INB', formula='',name='Tyrosine Hydroxylase before reaction',compartment='Brain')
## Glucose related
glc_D_c=M.metabolites.get_by_id('glc_D_c')
glc_D_BD=Metabolite('glc_D_BD', formula='C6H12O6',name='D-glucopyranose',compartment='Blood')
glc_D_e_INB=M.metabolites.get_by_id('glc_D_e_INB')

# reactions
## Glucose related reactions
###Glucose from liver to blood
GlcTR_TOBD = Reaction('GlcTR_TOBD')
GlcTR_TOBD.gene_reaction_rule = 'HGNC:1B'
M.add_reaction(GlcTR_TOBD)
M.reactions.GlcTR_TOBD.lower_bound = -1000
M.reactions.GlcTR_TOBD.upper_bound = 1000
M.reactions.GlcTR_TOBD.add_metabolites({glc_D_c:-1, glc_D_BD:1})
M.reactions.GlcTR_TOBD.name = 'Transport reaction of Glucose from liver to blood'
###Glc transport to brain
GlcTR_TOB = Reaction('GlcTR_TOB')
GlcTR_TOB.gene_reaction_rule = 'HGNC:2B'
M.add_reaction(GlcTR_TOB)
M.reactions.GlcTR_TOB.lower_bound = -1000
M.reactions.GlcTR_TOB.upper_bound = 1000 
M.reactions.GlcTR_TOB.add_metabolites({glc_D_BD:-1,To5_BD:-1,glc_D_e_INB:1,Ti5_INB:1})
M.reactions.GlcTR_TOB.name = 'Transport reaction of Glucose from blood to brain'
## Phe related reactions
###Phe from liver to blood
PheTR_TOBD = Reaction('PheTR_TOBD')
PheTR_TOBD.gene_reaction_rule = 'HGNC:3B'
M.add_reaction(PheTR_TOBD)
M.reactions.PheTR_TOBD.lower_bound = -1000
M.reactions.PheTR_TOBD.upper_bound = 1000
M.reactions.PheTR_TOBD.add_metabolites({phe_L_c:-1, phe_L_BD:1})
M.reactions.PheTR_TOBD.name = 'Transport reaction of Phenylalanine from liver to blood'
###Phe transport to brain
PheTR_TOB = Reaction('PheTR_TOB')
PheTR_TOB.gene_reaction_rule = 'HGNC:4-1B'
M.add_reaction(PheTR_TOB)
M.reactions.PheTR_TOB.lower_bound = -1000
M.reactions.PheTR_TOB.upper_bound = 1000
M.reactions.PheTR_TOB.add_metabolites({phe_L_BD:-1,To11_BD:-1,phe_L_e_INB:1,Ti11_INB:1})
M.reactions.PheTR_TOB.name = 'Transport reaction of Phenylalanine from blood to brain'
### Phenylpyruvate transport to blood
PHPYRbtBD = Reaction('PHPYRbtBD')
PHPYRbtBD.gene_reaction_rule = 'HGNC:5B'
M.add_reaction(PHPYRbtBD)
M.reactions.PHPYRbtBD.lower_bound = 0 
M.reactions.PHPYRbtBD.upper_bound = 1000
M.reactions.PHPYRbtBD.add_metabolites({phpyr_e_INB:-1,phpyr_BD:1})
M.reactions.PHPYRbtBD.name = 'Transport of Phenylpyruvate from brain to blood'
### Phpyr_BD to Urine
EX_phpyr_BD = Reaction('EX_phpyr_BD')
EX_phpyr_BD.gene_reaction_rule = 'HGNC:6B'
M.add_reaction(EX_phpyr_BD)
M.reactions.EX_phpyr_BD.lower_bound = 0 
M.reactions.EX_phpyr_BD.upper_bound = 1000
M.reactions.EX_phpyr_BD.add_metabolites({phpyr_BD:-1})
M.reactions.EX_phpyr_BD.name = 'Transport of Phenylpyruvate from blood to urine'
### Phenylpyruvate transport from liver to blood
PHPYRbtBD1 = Reaction('PHPYRbtBD1')
PHPYRbtBD1.gene_reaction_rule = 'HGNC:7B'
M.add_reaction(PHPYRbtBD1)
M.reactions.PHPYRbtBD1.lower_bound = 0 
M.reactions.PHPYRbtBD1.upper_bound = 1000
M.reactions.PHPYRbtBD1.add_metabolites({phpyr_e:-1,phpyr_BD:1})
M.reactions.PHPYRbtBD1.name = 'Transport of Phenylpyruvate from liver to blood'


## Tyr related reactions
###Tyr from liver to blood
TyrTR_TOBD = Reaction('TyrTR_TOBD')
TyrTR_TOBD.gene_reaction_rule = 'HGNC:3B'
M.add_reaction(TyrTR_TOBD)
M.reactions.TyrTR_TOBD.lower_bound = -1000
M.reactions.TyrTR_TOBD.upper_bound = 1000
M.reactions.TyrTR_TOBD.add_metabolites({tyr_L_c:-1, tyr_L_BD:1})
M.reactions.TyrTR_TOBD.name = 'Transport reaction of Tyrosine from liver to blood'
###Tyr transport to brain
TyrTR_TOB = Reaction('TyrTR_TOB')
TyrTR_TOB.gene_reaction_rule = 'HGNC:4-2B'
M.add_reaction(TyrTR_TOB)
M.reactions.TyrTR_TOB.lower_bound = -1000
M.reactions.TyrTR_TOB.upper_bound = 1000 
M.reactions.TyrTR_TOB.add_metabolites({tyr_L_BD:-1,To12_BD:-1,tyr_L_e_INB:1,Ti12_INB:1})
M.reactions.TyrTR_TOB.name = 'Transport reaction of Tyrosine from blood to brain'

## His related reactions
###His from liver to blood
HisTR_TOBD = Reaction('HisTR_TOBD')
HisTR_TOBD.gene_reaction_rule = 'HGNC:8B'
M.add_reaction(HisTR_TOBD)
M.reactions.HisTR_TOBD.lower_bound = -1000
M.reactions.HisTR_TOBD.upper_bound = 1000
M.reactions.HisTR_TOBD.add_metabolites({his_L_c:-1, his_L_BD:1})
M.reactions.HisTR_TOBD.name = 'Transport reaction of Histidine from liver to blood'
###His transport to brain
HisTR_TOB = Reaction('HisTR_TOB')
HisTR_TOB.gene_reaction_rule = 'HGNC:9B'
M.add_reaction(HisTR_TOB)
M.reactions.HisTR_TOB.lower_bound = -1000
M.reactions.HisTR_TOB.upper_bound = 1000 
M.reactions.HisTR_TOB.add_metabolites({his_L_BD:-1,To2_BD:-1,his_L_e_INB:1,Ti2_INB:1})
M.reactions.HisTR_TOB.name = 'Transport reaction of Histidine from blood to brain'

## Ile related reactions
###Ile from liver to blood
IleTR_TOBD = Reaction('IleTR_TOBD')
IleTR_TOBD.gene_reaction_rule = 'HGNC:8B'
M.add_reaction(IleTR_TOBD)
M.reactions.IleTR_TOBD.lower_bound = -1000
M.reactions.IleTR_TOBD.upper_bound = 1000
M.reactions.IleTR_TOBD.add_metabolites({ile_L_c:-1, ile_L_BD:1})
M.reactions.IleTR_TOBD.name = 'transport reaction of Isoleucine from liver to blood'
###Ile transport to brain
IleTR_TOB = Reaction('IleTR_TOB')
IleTR_TOB.gene_reaction_rule = 'HGNC:9B'
M.add_reaction(IleTR_TOB)
M.reactions.IleTR_TOB.lower_bound = -1000
M.reactions.IleTR_TOB.upper_bound = 1000 
M.reactions.IleTR_TOB.add_metabolites({ile_L_BD:-1,To2_BD:-1,ile_L_e_INB:1,Ti2_INB:1})
M.reactions.IleTR_TOB.name = 'transport reaction of Isoleucine from blood to brain'

## Leu related reactions
###Leu from liver to blood
LeuTR_TOBD = Reaction('LeuTR_TOBD')
LeuTR_TOBD.gene_reaction_rule = 'HGNC:8B'
M.add_reaction(LeuTR_TOBD)
M.reactions.LeuTR_TOBD.lower_bound = -1000
M.reactions.LeuTR_TOBD.upper_bound = 1000
M.reactions.LeuTR_TOBD.add_metabolites({leu_L_c:-1, leu_L_BD:1})
M.reactions.LeuTR_TOBD.name = 'transport reaction of Leucine from liver to blood'
###Leu transport to brain
LeuTR_TOB = Reaction('LeuTR_TOB')
LeuTR_TOB.gene_reaction_rule = 'HGNC:9B'
M.add_reaction(LeuTR_TOB)
M.reactions.LeuTR_TOB.lower_bound = -1000
M.reactions.LeuTR_TOB.upper_bound = 1000 
M.reactions.LeuTR_TOB.add_metabolites({leu_L_BD:-1,To2_BD:-1,leu_L_e_INB:1,Ti2_INB:1})
M.reactions.LeuTR_TOB.name = 'transport reaction of Leucine from blood to brain'

## Met related reactions
###Met from liver to blood
MetTR_TOBD = Reaction('MetTR_TOBD')
MetTR_TOBD.gene_reaction_rule = 'HGNC:8B'
M.add_reaction(MetTR_TOBD)
M.reactions.MetTR_TOBD.lower_bound = -1000
M.reactions.MetTR_TOBD.upper_bound = 1000
M.reactions.MetTR_TOBD.add_metabolites({met_L_c:-1, met_L_BD:1})
M.reactions.MetTR_TOBD.name = 'transport reaction of Methionine from liver to blood'
###Met transport to brain
MetTR_TOB = Reaction('MetTR_TOB')
MetTR_TOB.gene_reaction_rule = 'HGNC:9B'
M.add_reaction(MetTR_TOB)
M.reactions.MetTR_TOB.lower_bound = -1000
M.reactions.MetTR_TOB.upper_bound = 1000 
M.reactions.MetTR_TOB.add_metabolites({met_L_BD:-1,To2_BD:-1,met_L_e_INB:1,Ti2_INB:1})
M.reactions.MetTR_TOB.name = 'transport reaction of Methionine from blood to brain'

## Thr related reactions
###Thr from liver to blood
ThrTR_TOBD = Reaction('ThrTR_TOBD')
ThrTR_TOBD.gene_reaction_rule = 'HGNC:8B'
M.add_reaction(ThrTR_TOBD)
M.reactions.ThrTR_TOBD.lower_bound = -1000
M.reactions.ThrTR_TOBD.upper_bound = 1000
M.reactions.ThrTR_TOBD.add_metabolites({thr_L_c:-1, thr_L_BD:1})
M.reactions.ThrTR_TOBD.name = 'transport reaction of Threonine from liver to blood'
###Thr transport to brain
ThrTR_TOB = Reaction('ThrTR_TOB')
ThrTR_TOB.gene_reaction_rule = 'HGNC:9B'
M.add_reaction(ThrTR_TOB)
M.reactions.ThrTR_TOB.lower_bound = -1000
M.reactions.ThrTR_TOB.upper_bound = 1000 
M.reactions.ThrTR_TOB.add_metabolites({thr_L_BD:-1,To2_BD:-1,thr_L_e_INB:1,Ti2_INB:1})
M.reactions.ThrTR_TOB.name = 'transport reaction of Threonine from blood to brain'

## Trp related reactions
###Trp from liver to blood
TrpTR_TOBD = Reaction('TrpTR_TOBD')
TrpTR_TOBD.gene_reaction_rule = 'HGNC:3B'
M.add_reaction(TrpTR_TOBD)
M.reactions.TrpTR_TOBD.lower_bound = -1000
M.reactions.TrpTR_TOBD.upper_bound = 1000
M.reactions.TrpTR_TOBD.add_metabolites({trp_L_c:-1, trp_L_BD:1})
M.reactions.TrpTR_TOBD.name = 'transport reaction of Tryptophan from liver to blood'
###Trp transport to brain
TrpTR_TOB = Reaction('TrpTR_TOB')
TrpTR_TOB.gene_reaction_rule = 'HGNC:4-3B'
M.add_reaction(TrpTR_TOB)
M.reactions.TrpTR_TOB.lower_bound = -1000
M.reactions.TrpTR_TOB.upper_bound = 1000 
M.reactions.TrpTR_TOB.add_metabolites({trp_L_BD:-1,To13_BD:-1,trp_L_e_INB:1,Ti13_INB:1})
M.reactions.TrpTR_TOB.name = 'transport reaction of Tryptophan from blood to brain'

## Val related reactions
###Val from liver to blood
ValTR_TOBD = Reaction('ValTR_TOBD')
ValTR_TOBD.gene_reaction_rule = 'HGNC:8B'
M.add_reaction(ValTR_TOBD)
M.reactions.ValTR_TOBD.lower_bound = -1000
M.reactions.ValTR_TOBD.upper_bound = 1000
M.reactions.ValTR_TOBD.add_metabolites({val_L_c:-1, val_L_BD:1})
M.reactions.ValTR_TOBD.name = 'transport reaction of Valine from liver to blood'
###Val transport to brain
ValTR_TOB = Reaction('ValTR_TOB')
ValTR_TOB.gene_reaction_rule = 'HGNC:9B'
M.add_reaction(ValTR_TOB)
M.reactions.ValTR_TOB.lower_bound = -1000
M.reactions.ValTR_TOB.upper_bound = 1000 
M.reactions.ValTR_TOB.add_metabolites({val_L_BD:-1,To2_BD:-1,val_L_e_INB:1,Ti2_INB:1})
M.reactions.ValTR_TOB.name = 'transport reaction of Valine from blood to brain'

## Lys related reactions
###Lys from liver to blood
LysTR_TOBD = Reaction('LysTR_TOBD')
LysTR_TOBD.gene_reaction_rule = 'HGNC:10B'
M.add_reaction(LysTR_TOBD)
M.reactions.LysTR_TOBD.lower_bound = -1000
M.reactions.LysTR_TOBD.upper_bound = 1000
M.reactions.LysTR_TOBD.add_metabolites({lys_L_c:-1, lys_L_BD:1})
M.reactions.LysTR_TOBD.name = 'transport reaction of Lysine from liver to blood'
###Lys transport to brain
LysTR_TOB = Reaction('LysTR_TOB')
LysTR_TOB.gene_reaction_rule = 'HGNC:11B'
M.add_reaction(LysTR_TOB)
M.reactions.LysTR_TOB.lower_bound = -1000
M.reactions.LysTR_TOB.upper_bound = 1000 
M.reactions.LysTR_TOB.add_metabolites({lys_L_BD:-1,To3_BD:-1,lys_L_e_INB:1,Ti3_INB:1})
M.reactions.LysTR_TOB.name = 'transport reaction of Lysine from blood to brain'

## Ala related reactions
###Ala from liver to blood
AlaTR_TOBD = Reaction('AlaTR_TOBD')
AlaTR_TOBD.gene_reaction_rule = 'HGNC:12B'
M.add_reaction(AlaTR_TOBD)
M.reactions.AlaTR_TOBD.lower_bound = -1000
M.reactions.AlaTR_TOBD.upper_bound = 1000
M.reactions.AlaTR_TOBD.add_metabolites({ala_L_c:-1, ala_L_BD:1})
M.reactions.AlaTR_TOBD.name = 'transport reaction of Alanine from liver to blood'
###Ala transport to brain
AlaTR_TOB = Reaction('AlaTR_TOB')
AlaTR_TOB.gene_reaction_rule = 'HGNC:13B'
M.add_reaction(AlaTR_TOB)
M.reactions.AlaTR_TOB.lower_bound = -1000
M.reactions.AlaTR_TOB.upper_bound = 1000 
M.reactions.AlaTR_TOB.add_metabolites({ala_L_BD:-1,To4_BD:-1,ala_L_e_INB:1,Ti4_INB:1})
M.reactions.AlaTR_TOB.name = 'transport reaction of Alanine from blood to brain'

## Arg related reactions
###Arg from liver to blood
ArgTR_TOBD = Reaction('ArgTR_TOBD')
ArgTR_TOBD.gene_reaction_rule = 'HGNC:12B'
M.add_reaction(ArgTR_TOBD)
M.reactions.ArgTR_TOBD.lower_bound = -1000
M.reactions.ArgTR_TOBD.upper_bound = 1000
M.reactions.ArgTR_TOBD.add_metabolites({arg_L_c:-1, arg_L_BD:1})
M.reactions.ArgTR_TOBD.name = 'transport reaction of Arginine from liver to blood'
###Arg transport to brain
ArgTR_TOB = Reaction('ArgTR_TOB')
ArgTR_TOB.gene_reaction_rule = 'HGNC:13B'
M.add_reaction(ArgTR_TOB)
M.reactions.ArgTR_TOB.lower_bound = -1000
M.reactions.ArgTR_TOB.upper_bound = 1000 
M.reactions.ArgTR_TOB.add_metabolites({arg_L_BD:-1,To4_BD:-1,arg_L_e_INB:1,Ti4_INB:1})
M.reactions.ArgTR_TOB.name = 'transport reaction of Arginine from blood to brain'

## Asn related reactions
###Asn from liver to blood
AsnTR_TOBD = Reaction('AsnTR_TOBD')
AsnTR_TOBD.gene_reaction_rule = 'HGNC:12B'
M.add_reaction(AsnTR_TOBD)
M.reactions.AsnTR_TOBD.lower_bound = -1000
M.reactions.AsnTR_TOBD.upper_bound = 1000
M.reactions.AsnTR_TOBD.add_metabolites({asn_L_c:-1, asn_L_BD:1})
M.reactions.AsnTR_TOBD.name = 'transport reaction of Asparagine from liver to blood'
###Asn transport to brain
AsnTR_TOB = Reaction('AsnTR_TOB')
AsnTR_TOB.gene_reaction_rule = 'HGNC:13B'
M.add_reaction(AsnTR_TOB)
M.reactions.AsnTR_TOB.lower_bound = -1000
M.reactions.AsnTR_TOB.upper_bound = 1000 
M.reactions.AsnTR_TOB.add_metabolites({asn_L_BD:-1,To4_BD:-1,asn_L_e_INB:1,Ti4_INB:1})
M.reactions.AsnTR_TOB.name = 'transport reaction of Asparagine from blood to brain'

## Asp related reactions
###Asp from liver to blood
AspTR_TOBD = Reaction('AspTR_TOBD')
AspTR_TOBD.gene_reaction_rule = 'HGNC:12B'
M.add_reaction(AspTR_TOBD)
M.reactions.AspTR_TOBD.lower_bound = -1000
M.reactions.AspTR_TOBD.upper_bound = 1000
M.reactions.AspTR_TOBD.add_metabolites({asp_L_c:-1, asp_L_BD:1})
M.reactions.AspTR_TOBD.name = 'transport reaction of Aspartic acid from liver to blood'
###Asp transport to brain
AspTR_TOB = Reaction('AspTR_TOB')
AspTR_TOB.gene_reaction_rule = 'HGNC:13B'
M.add_reaction(AspTR_TOB)
M.reactions.AspTR_TOB.lower_bound = -1000
M.reactions.AspTR_TOB.upper_bound = 1000 
M.reactions.AspTR_TOB.add_metabolites({asp_L_BD:-1,To4_BD:-1,asp_L_e_INB:1,Ti4_INB:1})
M.reactions.AspTR_TOB.name = 'transport reaction of Aspartic acid from blood to brain'

## Cys related reactions
###Cys from liver to blood
CysTR_TOBD = Reaction('CysTR_TOBD')
CysTR_TOBD.gene_reaction_rule = 'HGNC:12B'
M.add_reaction(CysTR_TOBD)
M.reactions.CysTR_TOBD.lower_bound = -1000
M.reactions.CysTR_TOBD.upper_bound = 1000
M.reactions.CysTR_TOBD.add_metabolites({cys_L_c:-1, cys_L_BD:1})
M.reactions.CysTR_TOBD.name = 'transport reaction of Cysteine from liver to blood'
###Cys transport to brain
CysTR_TOB = Reaction('CysTR_TOB')
CysTR_TOB.gene_reaction_rule = 'HGNC:13B'
M.add_reaction(CysTR_TOB)
M.reactions.CysTR_TOB.lower_bound = -1000
M.reactions.CysTR_TOB.upper_bound = 1000 
M.reactions.CysTR_TOB.add_metabolites({cys_L_BD:-1,To4_BD:-1,cys_L_e_INB:1,Ti4_INB:1})
M.reactions.CysTR_TOB.name = 'transport reaction of Cysteine from blood to brain'

## Glu related reactions
###Glu from liver to blood
GluTR_TOBD = Reaction('GluTR_TOBD')
GluTR_TOBD.gene_reaction_rule = 'HGNC:12B'
M.add_reaction(GluTR_TOBD)
M.reactions.GluTR_TOBD.lower_bound = -1000
M.reactions.GluTR_TOBD.upper_bound = 1000
M.reactions.GluTR_TOBD.add_metabolites({glu_L_c:-1, glu_L_BD:1})
M.reactions.GluTR_TOBD.name = 'transport reaction of Glutamic acid from liver to blood'
###Glu transport to brain
GluTR_TOB = Reaction('GluTR_TOB')
GluTR_TOB.gene_reaction_rule = 'HGNC:13B'
M.add_reaction(GluTR_TOB)
M.reactions.GluTR_TOB.lower_bound = -1000
M.reactions.GluTR_TOB.upper_bound = 1000 
M.reactions.GluTR_TOB.add_metabolites({glu_L_BD:-1,To4_BD:-1,glu_L_e_INB:1,Ti4_INB:1})
M.reactions.GluTR_TOB.name = 'transport reaction of Glutamic acid from blood to brain'

## Gln related reactions
###Gln from liver to blood
GlnTR_TOBD = Reaction('GlnTR_TOBD')
GlnTR_TOBD.gene_reaction_rule = 'HGNC:12B'
M.add_reaction(GlnTR_TOBD)
M.reactions.GlnTR_TOBD.lower_bound = -1000
M.reactions.GlnTR_TOBD.upper_bound = 1000
M.reactions.GlnTR_TOBD.add_metabolites({gln_L_c:-1, gln_L_BD:1})
M.reactions.GlnTR_TOBD.name = 'transport reaction of Glutamate from liver to blood'
###Gln transport to brain
GlnTR_TOB = Reaction('GlnTR_TOB')
GlnTR_TOB.gene_reaction_rule = 'HGNC:13B'
M.add_reaction(GlnTR_TOB)
M.reactions.GlnTR_TOB.lower_bound = -1000
M.reactions.GlnTR_TOB.upper_bound = 1000 
M.reactions.GlnTR_TOB.add_metabolites({gln_L_BD:-1,To4_BD:-1,gln_L_e_INB:1,Ti4_INB:1})
M.reactions.GlnTR_TOB.name = 'transport reaction of Glutamine from blood to brain'

## Gly related reactions
###Gly from liver to blood
GlyTR_TOBD = Reaction('GlyTR_TOBD')
GlyTR_TOBD.gene_reaction_rule = 'HGNC:12B'
M.add_reaction(GlyTR_TOBD)
M.reactions.GlyTR_TOBD.lower_bound = -1000
M.reactions.GlyTR_TOBD.upper_bound = 1000
M.reactions.GlyTR_TOBD.add_metabolites({gly_c:-1, gly_BD:1})
M.reactions.GlyTR_TOBD.name = 'transport reaction of Glycine from liver to blood'
###Gly transport to brain
GlyTR_TOB = Reaction('GlyTR_TOB')
GlyTR_TOB.gene_reaction_rule = 'HGNC:13B'
M.add_reaction(GlyTR_TOB)
M.reactions.GlyTR_TOB.lower_bound = -1000
M.reactions.GlyTR_TOB.upper_bound = 1000 
M.reactions.GlyTR_TOB.add_metabolites({gly_BD:-1,To4_BD:-1,gly_e_INB:1,Ti4_INB:1})
M.reactions.GlyTR_TOB.name = 'transport reaction of Glycine from blood to brain'

## Pro related reactions
###Pro from liver to blood
ProTR_TOBD = Reaction('ProTR_TOBD')
ProTR_TOBD.gene_reaction_rule = 'HGNC:12B'
M.add_reaction(ProTR_TOBD)
M.reactions.ProTR_TOBD.lower_bound = -1000
M.reactions.ProTR_TOBD.upper_bound = 1000
M.reactions.ProTR_TOBD.add_metabolites({pro_L_c:-1, pro_L_BD:1})
M.reactions.ProTR_TOBD.name = 'transport reaction of Proline from liver to blood'
###Pro transport to brain
ProTR_TOB = Reaction('ProTR_TOB')
ProTR_TOB.gene_reaction_rule = 'HGNC:13B'
M.add_reaction(ProTR_TOB)
M.reactions.ProTR_TOB.lower_bound = -1000
M.reactions.ProTR_TOB.upper_bound = 1000 
M.reactions.ProTR_TOB.add_metabolites({pro_L_BD:-1,To4_BD:-1,pro_L_e_INB:1,Ti4_INB:1})
M.reactions.ProTR_TOB.name = 'transport reaction of Proline from blood to brain'

## Ser related reactions
###Ser from liver to blood
SerTR_TOBD = Reaction('SerTR_TOBD')
SerTR_TOBD.gene_reaction_rule = 'HGNC:12B'
M.add_reaction(SerTR_TOBD)
M.reactions.SerTR_TOBD.lower_bound = -1000
M.reactions.SerTR_TOBD.upper_bound = 1000
M.reactions.SerTR_TOBD.add_metabolites({ser_L_c:-1, ser_L_BD:1})
M.reactions.SerTR_TOBD.name = 'transport reaction of Serine from liver to blood'
###Ser transport to brain
SerTR_TOB = Reaction('SerTR_TOB')
SerTR_TOB.gene_reaction_rule = 'HGNC:13B'
M.add_reaction(SerTR_TOB)
M.reactions.SerTR_TOB.lower_bound = -1000
M.reactions.SerTR_TOB.upper_bound = 1000 
M.reactions.SerTR_TOB.add_metabolites({ser_L_BD:-1,To4_BD:-1,ser_L_e_INB:1,Ti4_INB:1})
M.reactions.SerTR_TOB.name = 'transport reaction of Serine from blood to brain'

## O2 related reactions
###O2 from liver to blood
O2TR_TOBD = Reaction('O2TR_TOBD')
O2TR_TOBD.gene_reaction_rule = 'HGNC:14B'
M.add_reaction(O2TR_TOBD)
M.reactions.O2TR_TOBD.lower_bound = -1000
M.reactions.O2TR_TOBD.upper_bound = 1000
M.reactions.O2TR_TOBD.add_metabolites({o2_c:-1, o2_BD:1})
M.reactions.O2TR_TOBD.name = 'transport reaction of O2 from liver to blood'
###O2 transport to brain
O2TR_TOB = Reaction('O2TR_TOB')
O2TR_TOB.gene_reaction_rule = 'HGNC:15B'
M.add_reaction(O2TR_TOB)
M.reactions.O2TR_TOB.lower_bound = -1000
M.reactions.O2TR_TOB.upper_bound = 1000 
M.reactions.O2TR_TOB.add_metabolites({o2_BD:-1,To6_BD:-1,o2_e_INB:1,Ti6_INB:1})
M.reactions.O2TR_TOB.name = 'transport reaction of O2 from blood to brain'

## NH4 related reactions
###NH4 from liver to blood
Nh4TR_TOBD = Reaction('Nh4TR_TOBD')
Nh4TR_TOBD.gene_reaction_rule = 'HGNC:16B'
M.add_reaction(Nh4TR_TOBD)
M.reactions.Nh4TR_TOBD.lower_bound = -1000
M.reactions.Nh4TR_TOBD.upper_bound = 1000
M.reactions.Nh4TR_TOBD.add_metabolites({nh4_c:-1, nh4_BD:1})
M.reactions.Nh4TR_TOBD.name = 'transport reaction of Ammonium from liver to blood'
###NH4 transport to brain
Nh4TR_TOB = Reaction('Nh4TR_TOB')
Nh4TR_TOB.gene_reaction_rule = 'HGNC:17B'
M.add_reaction(Nh4TR_TOB)
M.reactions.Nh4TR_TOB.lower_bound = -1000
M.reactions.Nh4TR_TOB.upper_bound = 1000 
M.reactions.Nh4TR_TOB.add_metabolites({nh4_BD:-1,To7_BD:-1,nh4_e_INB:1,Ti7_INB:1})
M.reactions.Nh4TR_TOB.name = 'transport reaction of Ammonium from blood to brain'

## Pi related reactions
###Pi from liver to blood
PiTR_TOBD = Reaction('PiTR_TOBD')
PiTR_TOBD.gene_reaction_rule = 'HGNC:18B'
M.add_reaction(PiTR_TOBD)
M.reactions.PiTR_TOBD.lower_bound = -1000
M.reactions.PiTR_TOBD.upper_bound = 1000
M.reactions.PiTR_TOBD.add_metabolites({pi_c:-1, pi_BD:1})
M.reactions.PiTR_TOBD.name = 'transport reaction of Hydrogenphosphate from liver to blood'
###pi transport to brain
PiTR_TOB = Reaction('PiTR_TOB')
PiTR_TOB.gene_reaction_rule = 'HGNC:19B'
M.add_reaction(PiTR_TOB)
M.reactions.PiTR_TOB.lower_bound = -1000
M.reactions.PiTR_TOB.upper_bound = 1000 
M.reactions.PiTR_TOB.add_metabolites({pi_BD:-1,To8_BD:-1,pi_e_INB:1,Ti8_INB:1})
M.reactions.PiTR_TOB.name = 'transport reaction of Hydrogenphosphate from blood to brain'


# exchanges of transporter
## exchange reaction of To11_BD and transporter reaction
EX_To11_c_BD = Reaction('EX_To11_c_BD')
EX_To11_c_BD.gene_reaction_rule = 'HGNC:20-1B'
M.add_reaction(EX_To11_c_BD)
M.reactions.EX_To11_c_BD.lower_bound = -1000 
M.reactions.EX_To11_c_BD.upper_bound = 1000
M.reactions.EX_To11_c_BD.add_metabolites({To11_c_BD:-1})
M.reactions.EX_To11_c_BD.name = 'exchange reaction for transporter11_out'
## Transport reaction of To11_BD 
To11TRC = Reaction('To11TRC')
To11TRC.gene_reaction_rule = 'HGNC:21-1B'
M.add_reaction(To11TRC)
M.reactions.To11TRC.lower_bound = -1000 
M.reactions.To11TRC.upper_bound = 1000
M.reactions.To11TRC.add_metabolites({To11_c_BD:-1, To11_BD: 1})
M.reactions.To11TRC.name = 'transport reaction for transporter11_out to blood'
## transporter reaction
Ti11_To11 = Reaction('Ti11_To11')
Ti11_To11.gene_reaction_rule = 'HGNC:22-1B'
M.add_reaction(Ti11_To11)
M.reactions.Ti11_To11.lower_bound = -1000 
M.reactions.Ti11_To11.upper_bound = 1000
M.reactions.Ti11_To11.add_metabolites({Ti11_INB:-1, To11_BD: 1})
M.reactions.Ti11_To11.name = 'transporter11 move back to blood'

## exchange reaction of To12_BD and transporter reaction
EX_To12_c_BD = Reaction('EX_To12_c_BD')
EX_To12_c_BD.gene_reaction_rule = 'HGNC:20-2B'
M.add_reaction(EX_To12_c_BD)
M.reactions.EX_To12_c_BD.lower_bound = -1000 
M.reactions.EX_To12_c_BD.upper_bound = 1000
M.reactions.EX_To12_c_BD.add_metabolites({To12_c_BD:-1})
M.reactions.EX_To12_c_BD.name = 'exchange reaction for transporter12_out'
## Transport reaction of To12_BD 
To12TRC = Reaction('To12TRC')
To12TRC.gene_reaction_rule = 'HGNC:21-2B'
M.add_reaction(To12TRC)
M.reactions.To12TRC.lower_bound = -1000 
M.reactions.To12TRC.upper_bound = 1000
M.reactions.To12TRC.add_metabolites({To12_c_BD:-1, To12_BD: 1})
M.reactions.To12TRC.name = 'transport reaction for transporter12_out to blood'
## transporter reaction
Ti12_To12 = Reaction('Ti12_To12')
Ti12_To12.gene_reaction_rule = 'HGNC:22-2B'
M.add_reaction(Ti12_To12)
M.reactions.Ti12_To12.lower_bound = -1000 
M.reactions.Ti12_To12.upper_bound = 1000
M.reactions.Ti12_To12.add_metabolites({Ti12_INB:-1, To12_BD: 1})
M.reactions.Ti12_To12.name = 'transporter12 move back to blood'

## exchange reaction of To13_BD and transporter reaction
EX_To13_c_BD = Reaction('EX_To13_c_BD')
EX_To13_c_BD.gene_reaction_rule = 'HGNC:20-3B'
M.add_reaction(EX_To13_c_BD)
M.reactions.EX_To13_c_BD.lower_bound = -1000 
M.reactions.EX_To13_c_BD.upper_bound = 1000
M.reactions.EX_To13_c_BD.add_metabolites({To13_c_BD:-1})
M.reactions.EX_To13_c_BD.name = 'exchange reaction for transporter13_out'
## Transport reaction of To13_BD 
To13TRC = Reaction('To13TRC')
To13TRC.gene_reaction_rule = 'HGNC:21-3B'
M.add_reaction(To13TRC)
M.reactions.To13TRC.lower_bound = -1000 
M.reactions.To13TRC.upper_bound = 1000
M.reactions.To13TRC.add_metabolites({To13_c_BD:-1, To13_BD: 1})
M.reactions.To13TRC.name = 'transport reaction for transporter13_out to blood'
## transporter reaction
Ti13_To13 = Reaction('Ti13_To13')
Ti13_To13.gene_reaction_rule = 'HGNC:22-3B'
M.add_reaction(Ti13_To13)
M.reactions.Ti13_To13.lower_bound = -1000 
M.reactions.Ti13_To13.upper_bound = 1000
M.reactions.Ti13_To13.add_metabolites({Ti13_INB:-1, To13_BD: 1})
M.reactions.Ti13_To13.name = 'transporter13 move back to blood'

## exchange reaction of To14_BD and transporter reaction
EX_To14_c_BD = Reaction('EX_To14_c_BD')
EX_To14_c_BD.gene_reaction_rule = 'HGNC:20-4B'
M.add_reaction(EX_To14_c_BD)
M.reactions.EX_To14_c_BD.lower_bound = -1000 
M.reactions.EX_To14_c_BD.upper_bound = 1000
M.reactions.EX_To14_c_BD.add_metabolites({To14_c_BD:-1})
M.reactions.EX_To14_c_BD.name = 'exchange reaction for transporter14_out'
## Transport reaction of To14_BD 
To14TRC = Reaction('To14TRC')
To14TRC.gene_reaction_rule = 'HGNC:21-4B'
M.add_reaction(To14TRC)
M.reactions.To14TRC.lower_bound = -1000 
M.reactions.To14TRC.upper_bound = 1000
M.reactions.To14TRC.add_metabolites({To14_c_BD:-1, To14_BD: 1})
M.reactions.To14TRC.name = 'transport reaction for transporter14_out to blood'
## transporter reaction
Ti14_To14 = Reaction('Ti14_To14')
Ti14_To14.gene_reaction_rule = 'HGNC:22-4B'
M.add_reaction(Ti14_To14)
M.reactions.Ti14_To14.lower_bound = -1000 
M.reactions.Ti14_To14.upper_bound = 1000
M.reactions.Ti14_To14.add_metabolites({Ti14_INB:-1, To14_BD: 1})
M.reactions.Ti14_To14.name = 'transporter14 move back to blood'

## exchange reaction of To2_BD and transporter reaction
EX_To2_c_BD = Reaction('EX_To2_c_BD')
EX_To2_c_BD.gene_reaction_rule = 'HGNC:23B'
M.add_reaction(EX_To2_c_BD)
M.reactions.EX_To2_c_BD.lower_bound = -1000 
M.reactions.EX_To2_c_BD.upper_bound = 1000
M.reactions.EX_To2_c_BD.add_metabolites({To2_c_BD:-1})
M.reactions.EX_To2_c_BD.name = 'exchange reaction for transporter2_out'
## Transport reaction of To2_BD 
To2TRC = Reaction('To2TRC')
To2TRC.gene_reaction_rule = 'HGNC:24B'
M.add_reaction(To2TRC)
M.reactions.To2TRC.lower_bound = -1000 
M.reactions.To2TRC.upper_bound = 1000
M.reactions.To2TRC.add_metabolites({To2_c_BD:-1, To2_BD: 1})
M.reactions.To2TRC.name = 'transport reaction for transporter2_out to blood'
## transporter reaction
Ti2_To2 = Reaction('Ti2_To2')
Ti2_To2.gene_reaction_rule = 'HGNC:25B'
M.add_reaction(Ti2_To2)
M.reactions.Ti2_To2.lower_bound = -1000 
M.reactions.Ti2_To2.upper_bound = 1000
M.reactions.Ti2_To2.add_metabolites({Ti2_INB:-1, To2_BD: 1})
M.reactions.Ti2_To2.name = 'transporter2 move back to blood'

## exchange reaction of To3_BD and transporter reaction
EX_To3_c_BD = Reaction('EX_To3_c_BD')
EX_To3_c_BD.gene_reaction_rule = 'HGNC:26B'
M.add_reaction(EX_To3_c_BD)
M.reactions.EX_To3_c_BD.lower_bound = -1000 
M.reactions.EX_To3_c_BD.upper_bound = 1000
M.reactions.EX_To3_c_BD.add_metabolites({To3_c_BD:-1})
M.reactions.EX_To3_c_BD.name = 'exchange reaction for transporter3_out'
## Transport reaction of To3_BD 
To3TRC = Reaction('To3TRC')
To3TRC.gene_reaction_rule = 'HGNC:27B'
M.add_reaction(To3TRC)
M.reactions.To3TRC.lower_bound = -1000 
M.reactions.To3TRC.upper_bound = 1000
M.reactions.To3TRC.add_metabolites({To3_c_BD:-1, To3_BD: 1})
M.reactions.To3TRC.name = 'transport reaction for transporter3_out to blood'
## transporter reaction
Ti3_To3 = Reaction('Ti3_To3')
Ti3_To3.gene_reaction_rule = 'HGNC:28B'
M.add_reaction(Ti3_To3)
M.reactions.Ti3_To3.lower_bound = -1000 
M.reactions.Ti3_To3.upper_bound = 1000
M.reactions.Ti3_To3.add_metabolites({Ti3_INB:-1, To3_BD: 1})
M.reactions.Ti3_To3.name = 'transporter3 move back to blood'

## exchange reaction of To4_BD and transporter reaction
EX_To4_c_BD = Reaction('EX_To4_c_BD')
EX_To4_c_BD.gene_reaction_rule = 'HGNC:29B'
M.add_reaction(EX_To4_c_BD)
M.reactions.EX_To4_c_BD.lower_bound = -1000 
M.reactions.EX_To4_c_BD.upper_bound = 1000
M.reactions.EX_To4_c_BD.add_metabolites({To4_c_BD:-1})
M.reactions.EX_To4_c_BD.name = 'exchange reaction for transporter4_out'
## Transport reaction of To4_BD 
To4TRC = Reaction('To4TRC')
To4TRC.gene_reaction_rule = 'HGNC:30B'
M.add_reaction(To4TRC)
M.reactions.To4TRC.lower_bound = -1000 
M.reactions.To4TRC.upper_bound = 1000
M.reactions.To4TRC.add_metabolites({To4_c_BD:-1, To4_BD: 1})
M.reactions.To4TRC.name = 'transport reaction for transporter4_out to blood'
## transporter reaction
Ti4_To4 = Reaction('Ti4_To4')
Ti4_To4.gene_reaction_rule = 'HGNC:31B'
M.add_reaction(Ti4_To4)
M.reactions.Ti4_To4.lower_bound = -1000 
M.reactions.Ti4_To4.upper_bound = 1000
M.reactions.Ti4_To4.add_metabolites({Ti4_INB:-1, To4_BD: 1})
M.reactions.Ti4_To4.name = 'transporter4 move back to blood'

## exchange reaction of To5_BD and transporter reaction
EX_To5_c_BD = Reaction('EX_To5_c_BD')
EX_To5_c_BD.gene_reaction_rule = 'HGNC:32B'
M.add_reaction(EX_To5_c_BD)
M.reactions.EX_To5_c_BD.lower_bound = -1000 
M.reactions.EX_To5_c_BD.upper_bound = 1000
M.reactions.EX_To5_c_BD.add_metabolites({To5_c_BD:-1})
M.reactions.EX_To5_c_BD.name = 'exchange reaction for transporter5_out'
## Transport reaction of To5_BD 
To5TRC = Reaction('To5TRC')
To5TRC.gene_reaction_rule = 'HGNC:33B'
M.add_reaction(To5TRC)
M.reactions.To5TRC.lower_bound = -1000 
M.reactions.To5TRC.upper_bound = 1000
M.reactions.To5TRC.add_metabolites({To5_c_BD:-1, To5_BD: 1})
M.reactions.To5TRC.name = 'transport reaction for transporter5_out to blood'
## transporter reaction
Ti5_To5 = Reaction('Ti5_To5')
Ti5_To5.gene_reaction_rule = 'HGNC:34B'
M.add_reaction(Ti5_To5)
M.reactions.Ti5_To5.lower_bound = -1000 
M.reactions.Ti5_To5.upper_bound = 1000
M.reactions.Ti5_To5.add_metabolites({Ti5_INB:-1, To5_BD: 1})
M.reactions.Ti5_To5.name = 'transporter5 move back to blood'

## exchange reaction of To6_BD and transporter reaction
EX_To6_c_BD = Reaction('EX_To6_c_BD')
EX_To6_c_BD.gene_reaction_rule = 'HGNC:35B'
M.add_reaction(EX_To6_c_BD)
M.reactions.EX_To6_c_BD.lower_bound = -1000 
M.reactions.EX_To6_c_BD.upper_bound = 1000
M.reactions.EX_To6_c_BD.add_metabolites({To6_c_BD:-1})
M.reactions.EX_To6_c_BD.name = 'exchange reaction for transporter6_out'
## Transport reaction of To6_BD 
To6TRC = Reaction('To6TRC')
To6TRC.gene_reaction_rule = 'HGNC:36B'
M.add_reaction(To6TRC)
M.reactions.To6TRC.lower_bound = -1000 
M.reactions.To6TRC.upper_bound = 1000
M.reactions.To6TRC.add_metabolites({To6_c_BD:-1, To6_BD: 1})
M.reactions.To6TRC.name = 'transport reaction for transporter6_out to blood'
## transporter reaction
Ti6_To6 = Reaction('Ti6_To6')
Ti6_To6.gene_reaction_rule = 'HGNC:37B'
M.add_reaction(Ti6_To6)
M.reactions.Ti6_To6.lower_bound = -1000 
M.reactions.Ti6_To6.upper_bound = 1000
M.reactions.Ti6_To6.add_metabolites({Ti6_INB:-1, To6_BD: 1})
M.reactions.Ti6_To6.name = 'transporter6 move back to blood'

## exchange reaction of To7_BD and transporter reaction
EX_To7_c_BD = Reaction('EX_To7_c_BD')
EX_To7_c_BD.gene_reaction_rule = 'HGNC:38B'
M.add_reaction(EX_To7_c_BD)
M.reactions.EX_To7_c_BD.lower_bound = -1000 
M.reactions.EX_To7_c_BD.upper_bound = 1000
M.reactions.EX_To7_c_BD.add_metabolites({To7_c_BD:-1})
M.reactions.EX_To7_c_BD.name = 'exchange reaction for transporter7_out'
## Transport reaction of To7_BD 
To7TRC = Reaction('To7TRC')
To7TRC.gene_reaction_rule = 'HGNC:39B'
M.add_reaction(To7TRC)
M.reactions.To7TRC.lower_bound = -1000 
M.reactions.To7TRC.upper_bound = 1000
M.reactions.To7TRC.add_metabolites({To7_c_BD:-1, To7_BD: 1})
M.reactions.To7TRC.name = 'transport reaction for transporter7_out to blood'
## transporter reaction
Ti7_To7 = Reaction('Ti7_To7')
Ti7_To7.gene_reaction_rule = 'HGNC:40B'
M.add_reaction(Ti7_To7)
M.reactions.Ti7_To7.lower_bound = -1000 
M.reactions.Ti7_To7.upper_bound = 1000
M.reactions.Ti7_To7.add_metabolites({Ti7_INB:-1, To7_BD: 1})
M.reactions.Ti7_To7.name = 'transporter7 move back to blood'

## exchange reaction of To8_BD and transporter reaction
EX_To8_c_BD = Reaction('EX_To8_c_BD')
EX_To8_c_BD.gene_reaction_rule = 'HGNC:41B'
M.add_reaction(EX_To8_c_BD)
M.reactions.EX_To8_c_BD.lower_bound = -1000 
M.reactions.EX_To8_c_BD.upper_bound = 1000
M.reactions.EX_To8_c_BD.add_metabolites({To8_c_BD:-1})
M.reactions.EX_To8_c_BD.name = 'exchange reaction for transporter8_out'
## Transport reaction of To8_BD 
To8TRC = Reaction('To8TRC')
To8TRC.gene_reaction_rule = 'HGNC:42B'
M.add_reaction(To8TRC)
M.reactions.To8TRC.lower_bound = -1000 
M.reactions.To8TRC.upper_bound = 1000
M.reactions.To8TRC.add_metabolites({To8_c_BD:-1, To8_BD: 1})
M.reactions.To8TRC.name = 'transport reaction for transporter8_out to blood'
## transporter reaction
Ti8_To8 = Reaction('Ti8_To8')
Ti8_To8.gene_reaction_rule = 'HGNC:43B'
M.add_reaction(Ti8_To8)
M.reactions.Ti8_To8.lower_bound = -1000 
M.reactions.Ti8_To8.upper_bound = 1000
M.reactions.Ti8_To8.add_metabolites({Ti8_INB:-1, To8_BD: 1})
M.reactions.Ti8_To8.name = 'transporter8 move back to blood'

# L-dopa related reactions
###L-dopa from liver to blood
LdopaTR_TOBD = Reaction('LdopaTR_TOBD')
LdopaTR_TOBD.gene_reaction_rule = 'HGNC:44B'
M.add_reaction(LdopaTR_TOBD)
M.reactions.LdopaTR_TOBD.lower_bound = -1000
M.reactions.LdopaTR_TOBD.upper_bound = 1000
M.reactions.LdopaTR_TOBD.add_metabolites({metabolite1:-1, metabolite2:1})
M.reactions.LdopaTR_TOBD.name = 'transport reaction of Levodopa from liver to blood'
###L-dopa from food or medicine to blood
EX_Ldopa_BD = Reaction('EX_Ldopa_BD')
EX_Ldopa_BD.gene_reaction_rule = 'HGNC:45B'
M.add_reaction(EX_Ldopa_BD)
M.reactions.EX_Ldopa_BD.lower_bound = 0
M.reactions.EX_Ldopa_BD.upper_bound = 1000
M.reactions.EX_Ldopa_BD.add_metabolites({metabolite2:-1})
M.reactions.EX_Ldopa_BD.name = 'Exchange reaction of Levodopa from food to blood'
###L-dopa transport to brain
LdopaTR_TOB = Reaction('LdopaTR_TOB')
LdopaTR_TOB.gene_reaction_rule = 'HGNC:46B'
M.add_reaction(LdopaTR_TOB)
M.reactions.LdopaTR_TOB.lower_bound = 0 
M.reactions.LdopaTR_TOB.upper_bound = 1000
M.reactions.LdopaTR_TOB.add_metabolites({metabolite2:-1,To14_BD:-1,metabolite:1,Ti14_INB:1})
M.reactions.LdopaTR_TOB.name = 'transport reaction of levodopa from blood to brain'


### Phe combined with Tyrosine Hydroxylase
Phe_TH_INB = Reaction('Phe_TH_INB')
Phe_TH_INB.gene_reaction_rule = 'HGNC:47B'
M.add_reaction(Phe_TH_INB)
M.reactions.Phe_TH_INB.lower_bound = 0 
M.reactions.Phe_TH_INB.upper_bound = 1000
M.reactions.Phe_TH_INB.add_metabolites({phe_L_c_INB:-1,TH_B_INB:-1,TH_A_INB:1,pheP_INB:1})
M.reactions.Phe_TH_INB.name = 'Phenylalanine catalyzed by tyrosine hydroxylase in brain'
### pheP degredation
PhePde_INB = Reaction('PhePde_INB')
PhePde_INB.gene_reaction_rule = 'HGNC:48B'
M.add_reaction(PhePde_INB)
M.reactions.PhePde_INB.lower_bound = 0 
M.reactions.PhePde_INB.upper_bound = 1000
M.reactions.PhePde_INB.add_metabolites({pheP_INB:-1})
M.reactions.PhePde_INB.name = 'Phenylalanine product degradation in brain'
###L-dopa production in brain
TYRDOPO1_INB = Reaction('TYRDOPO1_INB')
TYRDOPO1_INB.gene_reaction_rule = 'HGNC:49B'
M.add_reaction(TYRDOPO1_INB)
M.reactions.TYRDOPO1_INB.lower_bound = 0
M.reactions.TYRDOPO1_INB.upper_bound = 1000
M.reactions.TYRDOPO1_INB.add_metabolites({TH_B_INB:-1,tyr_L_c_INB:-1,metabolite3:1,TH_A_INB:1})
M.reactions.TYRDOPO1_INB.name = 'Levodopa production in brain'
## exchange reaction of Tyrosine Hydroxylase
EX_TH_B_INB = Reaction('EX_TH_B_INB')
EX_TH_B_INB.gene_reaction_rule = 'HGNC:50B'
M.add_reaction(EX_TH_B_INB)
M.reactions.EX_TH_B_INB.lower_bound = 0
M.reactions.EX_TH_B_INB.upper_bound = 1000
M.reactions.EX_TH_B_INB.add_metabolites({TH_B_INB:1})
M.reactions.EX_TH_B_INB.name = 'Tyrosine hydroxylase produced reaction'
##Tyrosine Hydroxylase after reaction to before reaction
TH_AToB_INB = Reaction('TH_AToB_INB')
TH_AToB_INB.gene_reaction_rule = 'HGNC:51B'
M.add_reaction(TH_AToB_INB)
M.reactions.TH_AToB_INB.lower_bound = 0
M.reactions.TH_AToB_INB.upper_bound = 1000
M.reactions.TH_AToB_INB.add_metabolites({TH_A_INB:-1,TH_B_INB:1})
M.reactions.TH_AToB_INB.name = 'Tyrosine hydroxylase after reaction to before reaction'


cobra.io.save_json_model(M, "Recon2.2plusthreeIndependent.json")
# Out:
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled
